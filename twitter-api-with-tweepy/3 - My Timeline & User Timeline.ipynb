# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.8/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.15.4 in ./venv/lib/python3.8/site-packages (from pandas) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./venv/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in ./venv/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# WARNING: You are using pip version 19.2.3, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
consumer_key ="AeUQkUTUkMwoxDkFq1uxgZImO"
consumer_secret = "wod7s7HZOOmvn042Us9L42qsCGkUGPJAFRv1RCiyvgF6abNXDW"
callback_uri = 'oob'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
redirect_url = auth.get_authorization_url()
webbrowser.open(redirect_url)
user_pint_input = input("What's the pin value? ")
auth.get_access_token(user_pint_input)
# Out:
# What's the pin value? 9336725
# ('895044554688212992-UGzkKooNF5RBzjFYVD5L0STw5de8m5G',
#  'dBv1FcV1SJsrx60vuEwWxZS9mxvyzzWV6blg9v4qCpHp2')

# %%
api = tweepy.API(auth)

# %%
me = api.me()
me.screen_name
# Out:
# 'elfieeeeeeeee'

# %%
my_timeline = api.home_timeline()
# print(my_timline)

# %%
allowed_types = [str, int]
tweets_data = []
columns = set()
for status in my_timeline:
    print(status.author.screen_name)
    # print(type(vars(status)))
    status_dict = dict(vars(status))
    keys = status_dict.keys()
    single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
    for k in keys:
        try:
            v_type = type(status_dict[k])
        except:
            v_type = None
        if v_type != None:
            if v_type in allowed_types:
                single_tweet_data[k] = status_dict[k]
                columns.add(k)
    tweets_data.append(single_tweet_data)
        
header_cols = list(columns)
header_cols.append("user")
header_cols.append('author')
# Out:
# daily_simaenaga
# daily_simaenaga
# Osaka_Kaiyukan
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga
# daily_simaenaga

# %%
df = pd.DataFrame(tweets_data, columns=header_cols)
df.head()
# Out:
#    favorite_count                                               text  \
# 0               0  RT @KoboNishioka: 以前、工房西岡のシマエナガを取り上げて下さった『ぼく、し...
# 1             701  札幌市内の図書施設すべてに写真集を寄贈したよ。書架に並ぶのはもうちょっと先になると思うけど、...
# 2            1563  8月末より日本の森水槽で暮らしているのは、ナツとリンの親子。\n2頭そろって展示水槽デビュー...
# 3            1283  おはエナガ（･▴･）げつようのあさは #しまくじ で運だめし なにがでるかな？ https:...
# 4             672  boku_simaenagaさんがユニクロのUTme!でオリジナルデザインを出品しています。...
#
#                   source  retweet_count                   id  \
# 0        Twitter Web App             24  1302939926967721984
# 1        Twitter Web App            112  1302917882272120833
# 2        Twitter Web App            318  1302891557494820864
# 3  SocialDog for Twitter            307  1302728333390753792
# 4        Twitter Web App            114  1302429895318855680
#
#    quoted_status_id               id_str                  source_url  \
# 0               NaN  1302939926967721984  https://mobile.twitter.com
# 1               NaN  1302917882272120833  https://mobile.twitter.com
# 2               NaN  1302891557494820864  https://mobile.twitter.com
# 3               NaN  1302728333390753792     https://social-dog.net/
# 4               NaN  1302429895318855680  https://mobile.twitter.com
#
#   quoted_status_id_str lang             user           author
# 0                  NaN   ja  daily_simaenaga  daily_simaenaga
# 1                  NaN   ja  daily_simaenaga  daily_simaenaga
# 2                  NaN   ja   Osaka_Kaiyukan   Osaka_Kaiyukan
# 3                  NaN   ja  daily_simaenaga  daily_simaenaga
# 4                  NaN   ja  daily_simaenaga  daily_simaenaga

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
        for k in keys:
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    single_tweet_data[k] = status_dict[k]
                    columns.add(k)
        tweets_data.append(single_tweet_data)


    header_cols = list(columns)
    header_cols.append("user")
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
my_timeline = api.home_timeline()

# %%
df2 = extract_timeline_as_df(my_timeline)
df2.head()
# Out:
#    favorite_count                                               text  \
# 0               0  RT @KoboNishioka: 以前、工房西岡のシマエナガを取り上げて下さった『ぼく、し...
# 1             701  札幌市内の図書施設すべてに写真集を寄贈したよ。書架に並ぶのはもうちょっと先になると思うけど、...
# 2            1570  8月末より日本の森水槽で暮らしているのは、ナツとリンの親子。\n2頭そろって展示水槽デビュー...
# 3            1284  おはエナガ（･▴･）げつようのあさは #しまくじ で運だめし なにがでるかな？ https:...
# 4             672  boku_simaenagaさんがユニクロのUTme!でオリジナルデザインを出品しています。...
#
#                   source  retweet_count                   id  \
# 0        Twitter Web App             24  1302939926967721984
# 1        Twitter Web App            112  1302917882272120833
# 2        Twitter Web App            319  1302891557494820864
# 3  SocialDog for Twitter            307  1302728333390753792
# 4        Twitter Web App            114  1302429895318855680
#
#    quoted_status_id               id_str                  source_url  \
# 0               NaN  1302939926967721984  https://mobile.twitter.com
# 1               NaN  1302917882272120833  https://mobile.twitter.com
# 2               NaN  1302891557494820864  https://mobile.twitter.com
# 3               NaN  1302728333390753792     https://social-dog.net/
# 4               NaN  1302429895318855680  https://mobile.twitter.com
#
#   quoted_status_id_str lang             user           author
# 0                  NaN   ja  daily_simaenaga  daily_simaenaga
# 1                  NaN   ja  daily_simaenaga  daily_simaenaga
# 2                  NaN   ja   Osaka_Kaiyukan   Osaka_Kaiyukan
# 3                  NaN   ja  daily_simaenaga  daily_simaenaga
# 4                  NaN   ja  daily_simaenaga  daily_simaenaga

# %%
user = api.get_user("code")
user_timeline = user.timeline()
df3 = extract_timeline_as_df(user_timeline)
df3.head()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x1137ed3d0>: Failed to establish a new connection: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?user_id=3167734591 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1137ed3d0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?user_id=3167734591 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1137ed3d0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-13-0474bc31d74b> in <module>
#       1 user = api.get_user("code")
# ----> 2 user_timeline = user.timeline()
#       3 df3 = extract_timeline_as_df(user_timeline)
#       4 df3.head()
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/tweepy/models.py in timeline(self, **kwargs)
#     176
#     177     def timeline(self, **kwargs):
# --> 178         return self._api.user_timeline(user_id=self.id, **kwargs)
#     179
#     180     def friends(self, **kwargs):
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
# --> 192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     193
#     194                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/six.py in reraise(tp, value, tb)
#     700                 value = tp()
#     701             if value.__traceback__ is not tb:
# --> 702                 raise value.with_traceback(tb)
#     703             raise value
#     704         finally:
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     182                 # Execute request
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#     186                                                 data=self.post_data,
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/Documents/30-day/twitter-api-with-tweepy/venv/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?user_id=3167734591 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1137ed3d0>: Failed to establish a new connection: [Errno 60] Operation timed out'))
