# %%
import os
import pandas as pd

# %%
cwd = os.getcwd() # dirname(abspath(__file__))
BASE_DIR = os.path.dirname(cwd)
DATA_DIR = os.path.join(BASE_DIR, 'data')
CACHE_DIR = os.path.join(BASE_DIR, 'cache')
working_file = os.path.join(CACHE_DIR, "movies-box-office-dataset.csv")

# %%
df = pd.read_csv(working_file)

# %%
df.head(n=10)
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0     1                                  Bad Boys for Life  $425,514,702
# 1     2                                 Sonic the Hedgehog  $306,766,470
# 2     3                                           Dolittle  $227,908,130
# 3     4  Birds of Prey: And the Fantabulous Emancipatio...  $201,858,461
# 4     5                                  The Invisible Man  $124,549,496
# 5     6                                      The Gentlemen  $117,769,345
# 6     7                               The Call of the Wild  $107,604,626
# 7     8                                         The Grudge   $49,511,319
# 8     9                                     Fantasy Island   $48,607,556
# 9    10                                         Underwater   $40,882,928
#
#        Domestic      %       Foreign    %.1  filename  year
# 0  $204,417,855    48%  $221,096,847    52%  2020.csv  2020
# 1  $146,066,470  47.6%  $160,700,000  52.4%  2020.csv  2020
# 2   $77,047,065  33.8%  $150,861,065  66.2%  2020.csv  2020
# 3   $84,158,461  41.7%  $117,700,000  58.3%  2020.csv  2020
# 4   $64,914,050  52.1%   $59,635,446  47.9%  2020.csv  2020
# 5   $36,296,853  30.8%   $81,472,492  69.2%  2020.csv  2020
# 6   $62,342,368  57.9%   $45,262,258  42.1%  2020.csv  2020
# 7   $21,221,803  42.9%   $28,289,516  57.1%  2020.csv  2020
# 8   $26,441,782  54.4%   $22,165,774  45.6%  2020.csv  2020
# 9   $17,291,078  42.3%   $23,591,850  57.7%  2020.csv  2020

# %%
df["Rank"]= -1

# %%
df.head()
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0    -1                                  Bad Boys for Life  $425,514,702
# 1    -1                                 Sonic the Hedgehog  $306,766,470
# 2    -1                                           Dolittle  $227,908,130
# 3    -1  Birds of Prey: And the Fantabulous Emancipatio...  $201,858,461
# 4    -1                                  The Invisible Man  $124,549,496
#
#        Domestic      %       Foreign    %.1  filename  year
# 0  $204,417,855    48%  $221,096,847    52%  2020.csv  2020
# 1  $146,066,470  47.6%  $160,700,000  52.4%  2020.csv  2020
# 2   $77,047,065  33.8%  $150,861,065  66.2%  2020.csv  2020
# 3   $84,158,461  41.7%  $117,700,000  58.3%  2020.csv  2020
# 4   $64,914,050  52.1%   $59,635,446  47.9%  2020.csv  2020

# %%
df['Domestic %'] = df['%']
df['Foreign %'] = df['%.1']
df.head()
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0    -1                                  Bad Boys for Life  $425,514,702
# 1    -1                                 Sonic the Hedgehog  $306,766,470
# 2    -1                                           Dolittle  $227,908,130
# 3    -1  Birds of Prey: And the Fantabulous Emancipatio...  $201,858,461
# 4    -1                                  The Invisible Man  $124,549,496
#
#        Domestic      %       Foreign    %.1  filename  year Domestic %  \
# 0  $204,417,855    48%  $221,096,847    52%  2020.csv  2020        48%
# 1  $146,066,470  47.6%  $160,700,000  52.4%  2020.csv  2020      47.6%
# 2   $77,047,065  33.8%  $150,861,065  66.2%  2020.csv  2020      33.8%
# 3   $84,158,461  41.7%  $117,700,000  58.3%  2020.csv  2020      41.7%
# 4   $64,914,050  52.1%   $59,635,446  47.9%  2020.csv  2020      52.1%
#
#   Foreign %
# 0       52%
# 1     52.4%
# 2     66.2%
# 3     58.3%
# 4     47.9%

# %%
# df.drop(columns=['%', '%.1'])
# df.drop(['%', '%.1'], axis=1)  #drop column
df.drop(['%', '%.1'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0    -1                                  Bad Boys for Life  $425,514,702
# 1    -1                                 Sonic the Hedgehog  $306,766,470
# 2    -1                                           Dolittle  $227,908,130
# 3    -1  Birds of Prey: And the Fantabulous Emancipatio...  $201,858,461
# 4    -1                                  The Invisible Man  $124,549,496
#
#        Domestic       Foreign  filename  year Domestic % Foreign %
# 0  $204,417,855  $221,096,847  2020.csv  2020        48%       52%
# 1  $146,066,470  $160,700,000  2020.csv  2020      47.6%     52.4%
# 2   $77,047,065  $150,861,065  2020.csv  2020      33.8%     66.2%
# 3   $84,158,461  $117,700,000  2020.csv  2020      41.7%     58.3%
# 4   $64,914,050   $59,635,446  2020.csv  2020      52.1%     47.9%

# %%
to_clean_cols = ['Worldwide', 'Domestic', 'Foreign']

def currency_str_to_int(current_val):
    currency_val = current_val.replace("$", "").replace(",", "")
    try:
        currency_val = int(currency_val)
    except:
        # Takes any row value with "-" and turns into 0
        currency_val = 0
    return currency_val 

def clean_col(row):
    """
    row = Pandas Series
    dataframe = collection of Pandas Series
    """
    # print(row)
    for col in to_clean_cols: 
        current_val = row[col] #get the value for each column row 
        row[col] = currency_str_to_int(current_val)#convert the cell value
    return row

df_cleaned = df.apply(clean_col, axis=1) #pass in row=1 #reassign the result to a new dataframe
df_cleaned.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/30-day/data-science-pipelin/venv/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-d209766871db> in <module>
#      21     return row
#      22
# ---> 23 df_cleaned = df.apply(clean_col, axis=2) #pass in row=1 #reassign the result to a new dataframe
#      24 df_cleaned.head()
#
# ~/Documents/30-day/data-science-pipelin/venv/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7534         from pandas.core.apply import frame_apply
#    7535
# -> 7536         op = frame_apply(
#    7537             self,
#    7538             func=func,
#
# ~/Documents/30-day/data-science-pipelin/venv/lib/python3.8/site-packages/pandas/core/apply.py in frame_apply(obj, func, axis, raw, result_type, ignore_failures, args, kwds)
#      32 ):
#      33     """ construct and return a row or column based frame apply object """
# ---> 34     axis = obj._get_axis_number(axis)
#      35     klass: Type[FrameApply]
#      36     if axis == 0:
#
# ~/Documents/30-day/data-science-pipelin/venv/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# --> 370             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     371
#     372     @classmethod
#
# ValueError: No axis named 2 for object type DataFrame

# %%
df_cleaned.dtypes #get datatypes
# Out:
# Rank              int64
# Release Group    object
# Worldwide         int64
# Domestic          int64
# Foreign           int64
# filename         object
# year              int64
# Domestic %       object
# Foreign %        object
# dtype: object
